# %%
import os
if os.getcwd().endswith("notebooks"):
    os.chdir("..")

import importlib
from IPython.display import display, Markdown, Latex
import numpy as np
import pandas as pd
pd.set_option("display.max_colwidth", None)
pd.set_option('display.max_rows', 500)

from src.utils import tree_utils
from src.features import feature_utils

# %%
data = feature_utils.load_trees_from_predictions(output_dir="/home/rabiraj.bandyopadhyay/ShortcutGrammar/src/output/subj/sexism",
                                                 dataset="sexism")
# Out:
# parsed 9322/9540 trees
# parsed 4002/4090 trees

# %%
data['dataset']
# Out:
# 'sexism'

# %%
df_tree = pd.DataFrame(data['train'])

# %%
df_tree.head()
# Out:
#   uid  \
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4
#
#                                                                                                                                        sentence  \
# 0                                                                                                                SIIIIGH http://t.co/BpJX5JwhlH
# 1                                             I really dislike working with undergrads in lab. Can I have my socially inept grad students back?
# 2  So calling qualified hires "tokens" b/c it's not enough is harmful to progress. It reinforces what we already feel around us. It’s an attack
# 3                                                                                                                          Noooooo #mkr whyyyyy
# 4                                                                            I don't know ANY genuine female nerds... who watch The View. #Thor
#
#    label  \
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 tree  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[[UNK]], [[(24 (5 (23 (43 http) (79 :)) (5 (31 (72 /) (72 /)) (54 t))) (74 .)), (66 co)], [(72 /), (50 [UNK])]]]
# 1                                                                                                                                                                                                                                                                                                                    [[[(14\n  (1 (68 i) (21 (81 really) (32 dislike)))\n  (2 (73 working) (15 (52 with) (60 [UNK])))), (15 (52 in) (60 [UNK]))], [(49 .), (14\n  (80 can)\n  (14\n    (8 (68 i) (32 have))\n    (2\n      (2\n        (11 (11 (11 (86 my) (88 socially)) (88 inept)) (88 grad))\n        (41 students))\n      (35 back))))]], [?]]
# 2  [[[(27\n  (27\n    (3 (92 so) (14 (8 (34 calling) (39 qualified)) (51 [UNK])))\n    (16\n      (49 ")\n      (14\n        (8\n          (29\n            (29\n              (29 (29 (51 [UNK]) (35 ")) (35 b))\n              (15 (72 /) (78 c)))\n            (15\n              (8 (8 (65 it) (26 (89 ') (70 s))) (81 not))\n              (46 enough)))\n          (77 is))\n        (51 [UNK]))))\n  (15 (91 to) (59 progress))), (16\n  (49 .)\n  (14\n    (8 (57 it) (56 [UNK]))\n    (2 (38 what) (14 (68 we) (19 (81 already) (61 feel))))))], [(52 around), (59 us)]], [[.], [(8 (65 it) (26 (89 ’) (70 s))), (2 (86 an) (48 attack))]]]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[[UNK]], [[(36 #), (75 mkr)], [[UNK]]]]
# 4                                                                                                                                                                                                                                                                                                                                                                   [[[(27\n  (27\n    (27\n      (1 (68 i) (21 (63 don) (10 (89 ') (9 (54 t) (61 know)))))\n      (29 (11 (11 (86 any) (88 [UNK])) (88 female)) (51 [UNK])))\n    (15 (74 .) (74 .)))\n  (16 (49 .) (14 (68 who) (19 (61 watch) (29 (86 the) (82 view)))))), (74 .)], [#]], [thor]]
#
#        y
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
df_tree.columns
# Out:
# Index(['uid', 'sentence', 'label', 'tree', 'y'], dtype='object')

# %%
df_tree[df_tree['label'] == True].head()
# Out:
#    uid  \
# 9    9
# 11  11
# 13  13
# 21  21
# 28  28
#
#                                                                                                                                        sentence  \
# 9                      FETISHIZATION ALERT MENTION3680 it's time for Fox to get a new sideline girl. i vote for a nice Filipina holding the mic
# 11  MENTION3181 Real women also have a good man at their side and ain't out there manipulating society with their "QUEER" intentions as values.
# 13                                              A true gentleman should not invite a young lady to come alone to his house, especially at night
# 21                                                                                “A good man is as strong as the right woman needs him to be.”
# 28                      RT MENTION837 Why do girls think it's an achievement to not wear make up, us boys don't wear it. #bestgender #notsexist
#
#     label  \
# 9    True
# 11   True
# 13   True
# 21   True
# 28   True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     tree  \
# 9                                                                                                                                                                                                                                                      [[[UNK]], [[alert], [(44 [UNK]), (25\n  (27\n    (27\n      (27\n        (14 (8 (65 it) (26 (89 ') (70 s))) (46 time))\n        (15\n          (52 for)\n          (29\n            (56 [UNK])\n            (6\n              (91 to)\n              (2\n                (87 get)\n                (29 (11 (11 (86 a) (88 new)) (88 [UNK])) (41 girl)))))))\n      (16 (49 .) (14 (68 i) (61 vote))))\n    (15 (52 for) (29 (11 (86 a) (88 nice)) (51 [UNK]))))\n  (15 (52 holding) (29 (86 the) (56 [UNK]))))]]]
# 11                                                                                                                                                                                                                            [[[UNK]], [[(27\n  (27\n    (27\n      (27\n        (14\n          (8 (29 (88 real) (53 women)) (77 also))\n          (2 (87 have) (29 (11 (86 a) (88 good)) (41 man))))\n        (15 (52 at) (29 (86 their) (82 side))))\n      (16\n        (49 and)\n        (14\n          (21\n            (63 ain)\n            (10 (89 ') (9 (54 t) (19 (61 out) (57 there)))))\n          (29 (56 [UNK]) (59 society)))))\n    (15 (52 with) (29 (11 (86 their) (88 ")) (41 queer))))\n  (15 (49 ") (44 [UNK]))), (15 (52 as) (59 values))], [.]]]
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[[(14\n  (8\n    (8 (29 (11 (86 a) (88 true)) (41 gentleman)) (77 should))\n    (81 not))\n  (2\n    (2 (87 invite) (29 (11 (86 a) (88 young)) (41 lady)))\n    (6 (91 to) (2 (78 come) (35 alone))))), (6 (91 to) (2 (86 his) (48 house)))], [(49 ,), (45 especially)]], [[at], [night]]]
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[“], [[(27\n  (27\n    (27\n      (14\n        (8 (29 (11 (86 a) (88 good)) (41 man)) (77 is))\n        (2 (42 as) (64 strong)))\n      (15 (52 as) (29 (11 (86 the) (88 right)) (41 woman))))\n    (15 (52 needs) (59 him)))\n  (15 (91 to) (42 be))), (74 .)], [”]]]
# 28  [[rt], [[[UNK]], [(17\n  (28\n    (17\n      (28\n        (27\n          (27\n            (14\n              (8\n                (68 why)\n                (22\n                  (61 do)\n                  (8\n                    (68 girls)\n                    (22 (61 think) (8 (65 it) (26 (89 ') (70 s)))))))\n              (2 (86 an) (48 achievement)))\n            (6\n              (91 to)\n              (2 (81 not) (2 (42 wear) (2 (87 make) (39 up))))))\n          (16\n            (49 ,)\n            (14\n              (29 (88 us) (53 boys))\n              (21\n                (63 don)\n                (10 (89 ') (9 (54 t) (2 (87 wear) (39 it))))))))\n        (74 .))\n      (36 #))\n    (60 [UNK]))\n  (36 #)), (75 notsexist)]]]
#
#        y
# 9   True
# 11  True
# 13  True
# 21  True
# 28  True

# %%
#df_tree.to_csv('train_trees.csv')

# %%
feature_utils.add_features_train(data['train'], "Subtrees", feature_utils.pcfg_subtrees)
subtrees = feature_utils.get_subtree_feature_table_train(data['train'], label_name = "sexism")
subtrees.head(10)
# Out:
# 138024 Subtrees features
#   Root             Subtree    Yield        MI   Count  Sexist  Non-Sexist  \
# 0   75              (75 *)      mkr  0.034546  2348.0  2336.0        12.0
# 1   57              (57 *)    women  0.018962   413.0   202.0       211.0
# 2   36              (36 *)        #  0.016675  3234.0  3066.0       168.0
# 3   57              (57 *)      men  0.012889   183.0    69.0       114.0
# 4   73              (73 *)   sexist  0.012883   186.0    71.0       115.0
# 5   82              (82 *)      man  0.012534   364.0   198.0       166.0
# 6   77              (77 *)   should  0.011944   583.0   367.0       216.0
# 7   82              (82 *)    woman  0.011847   340.0   184.0       156.0
# 8   29  (29 (86 *) (82 *))    a man  0.010637   304.0   164.0       140.0
# 9   29  (29 (86 *) (82 *))  a woman  0.010600   301.0   162.0       139.0
#
#   Majority label  % majority
# 0         Sexist    0.994468
# 1     Non-Sexist    0.510843
# 2         Sexist    0.947775
# 3     Non-Sexist    0.621622
# 4     Non-Sexist    0.617021
# 5         Sexist    0.543716
# 6         Sexist    0.629060
# 7         Sexist    0.540936
# 8         Sexist    0.539216
# 9         Sexist    0.537954

# %%
subtrees[subtrees['Majority label'] == 'Non-Sexist'].reset_index(drop = True).head(10)
# Out:
#   Root             Subtree         Yield        MI  Count  Sexist  Non-Sexist  \
# 0   57              (57 *)         women  0.018962  413.0   202.0       211.0
# 1   57              (57 *)           men  0.012889  183.0    69.0       114.0
# 2   73              (73 *)        sexist  0.012883  186.0    71.0       115.0
# 3   59              (59 *)           men  0.008900  163.0    72.0        91.0
# 4   88              (88 *)        female  0.008565  113.0    40.0        73.0
# 5   82              (82 *)          girl  0.006204  128.0    60.0        68.0
# 6   29  (29 (86 *) (82 *))        a girl  0.005721  106.0    47.0        59.0
# 7   15  (15 (52 *) (59 *))      than men  0.005198   40.0     7.0        33.0
# 8    8   (8 (57 *) (77 *))  women should  0.005134   74.0    28.0        46.0
# 9    8   (8 (57 *) (77 *))       men are  0.005053   48.0    12.0        36.0
#
#   Majority label  % majority
# 0     Non-Sexist    0.510843
# 1     Non-Sexist    0.621622
# 2     Non-Sexist    0.617021
# 3     Non-Sexist    0.557576
# 4     Non-Sexist    0.643478
# 5     Non-Sexist    0.530769
# 6     Non-Sexist    0.555556
# 7     Non-Sexist    0.809524
# 8     Non-Sexist    0.618421
# 9     Non-Sexist    0.740000

# %%
subtrees[subtrees['Majority label'] == 'Sexist'].reset_index(drop = True).head(10)
# Out:
#   Root             Subtree    Yield        MI   Count  Sexist  Non-Sexist  \
# 0   75              (75 *)      mkr  0.034546  2348.0  2336.0        12.0
# 1   36              (36 *)        #  0.016675  3234.0  3066.0       168.0
# 2   82              (82 *)      man  0.012534   364.0   198.0       166.0
# 3   77              (77 *)   should  0.011944   583.0   367.0       216.0
# 4   82              (82 *)    woman  0.011847   340.0   184.0       156.0
# 5   29  (29 (86 *) (82 *))    a man  0.010637   304.0   164.0       140.0
# 6   29  (29 (86 *) (82 *))  a woman  0.010600   301.0   162.0       139.0
# 7   86              (86 *)        a  0.007251  3055.0  2462.0       593.0
# 8   52              (52 *)     than  0.006733   384.0   248.0       136.0
# 9   89              (89 *)        ’  0.005585   182.0   102.0        80.0
#
#   Majority label  % majority
# 0         Sexist    0.994468
# 1         Sexist    0.947775
# 2         Sexist    0.543716
# 3         Sexist    0.629060
# 4         Sexist    0.540936
# 5         Sexist    0.539216
# 6         Sexist    0.537954
# 7         Sexist    0.805692
# 8         Sexist    0.645078
# 9         Sexist    0.559783

# %% [markdown]
# ## We follow the following steps:
# 1. First step is to get the roots that contain patterns that are spuriously correlated with the sexist class
# 2. 2nd step is to see the presence of the root in the sexist instances
# 3. For each of the roots check the PVI and EL2N score distribution
# 4. The distributions will tell a story

# %%
#df_train = pd.read_csv(os.path.join(os.path.expanduser('~/ShortcutGrammar'), 'sexist_data_final_train.csv'))

# %%
#df_train.columns

# %%
#df_train = df_train.rename(columns = {'Unnamed: 0':'row_id'})

# %%
#df_train = df_train[['row_id', 'id', 'text', 'numeric_labels', 'average_pvi', 'average_el2n', 'misclassification_number', 'sexist']]
#df_train['row_id'] = df_train['row_id'].astype(np.int64)

# %%
#df_train.head()

# %%
#df_tree.head()

# %%
#df_tree = df_tree.rename(columns = {'uid': 'row_id'})

# %%
#df_tree['row_id'] = df_tree['row_id'].astype(np.int64)

# %%
#df_resultant = df_tree.join(df_train, on = 'row_id', how = 'inner', lsuffix = '_tree', rsuffix = '_train')

# %%
#df_resultant = df_resultant[['id', 'text', 'average_pvi', 'average_el2n', 'misclassification_number', 
#                             'sexist', 'numeric_labels', 'tree']].reset_index(drop = True)
#df_resultant.head()

# %%
#df_resultant.to_csv('Resultant_DataFrame.csv', index = False)

# %%
#df_r_sexist = df_resultant[(df_resultant['sexist'] == True) & (df_resultant['misclassification_number'] == 0)].reset_index(drop = True)

# %%
#df_r_sexist.to_csv('sexist_easy_instances_trees.csv', index = False)

# %%
#df_r_non_sexist = df_resultant[(df_resultant['sexist'] == False) & (df_resultant['misclassification_number'] == 5)].reset_index(drop = True)

# %%
#df_r_non_sexist.to_csv('non_sexist_hard_instances_trees.csv', index = False)

# %%
feature_utils.add_merges_train(data['train'], "Subtrees", K=2000, merge_name="Subtree groups",
                         filter_=lambda w: w[0].count("*") <= 2)
# Out:
# filtering

# %%
df_feats = feature_utils.get_merged_feature_table_train(data['train'], merge_name="Subtree groups")

# %% [markdown]
# To visualize the most discriminative patterns, we group the highest-ranked subtrees according to their root label and majority class label.

# %%
df_feats_sexist = df_feats[df_feats['Majority label'] == 'Sexist'].reset_index(drop = True)
df_feats_sexist.head(10)
# Out:
#   Root  \
# 0    2
# 1   29
# 2   15
# 3   88
# 4   82
# 5   88
# 6   82
# 7    8
# 8    8
# 9   86
#
#                                                                                              Examples  \
# 0   take care, truly [UNK], more easily, hear girls, be permitted, being leered, stay home, be cooked
# 1                    a girl, her husband, a lady, the home, a female, a wife, a women, female rappers
# 2                     than men, than women, to men, for sex, by men, to women, with women, than girls
# 3                                          female, women, girl, girls, proper, career, physical, mens
# 4                                              girl, husband, wife, female, lady, home, men, emotions
# 5                                      sexual, male, [UNK], football, most, instant, greater, special
# 6                                               man, woman, women, children, guy, family, boy, career
# 7  women should, men are, girls should, men should, women have, women do, boys should, females should
# 8                           women are, it is, call me, i hate, there are, she has, this is, andre are
# 9                                                               involve, very, what, ‘, ’, “, ”, term
#
#          MI  Count  Sexist  Non-Sexist  Majority label idx Majority label  \
# 0  0.003713  275.0   275.0         0.0                   0         Sexist
# 1  0.002475  192.0   192.0         0.0                   0         Sexist
# 2  0.002357  184.0   184.0         0.0                   0         Sexist
# 3  0.001829  204.0   201.0         3.0                   0         Sexist
# 4  0.001787  145.0   145.0         0.0                   0         Sexist
# 5  0.001445  141.0   140.0         1.0                   0         Sexist
# 6  0.000753   72.0    72.0         0.0                   0         Sexist
# 7  0.000699   68.0    68.0         0.0                   0         Sexist
# 8  0.000511   54.0    54.0         0.0                   0         Sexist
# 9  0.000472   51.0    51.0         0.0                   0         Sexist
#
#    % majority  Support count  Counter count
# 0    0.996390          275.0            0.0
# 1    0.994845          192.0            0.0
# 2    0.994624          184.0            0.0
# 3    0.980583          201.0            3.0
# 4    0.993197          145.0            0.0
# 5    0.986014          140.0            1.0
# 6    0.986486           72.0            0.0
# 7    0.985714           68.0            0.0
# 8    0.982143           54.0            0.0
# 9    0.981132           51.0            0.0

# %%
df_feats_non_sexist = df_feats[df_feats['Majority label'] == 'Non-Sexist'].reset_index(drop = True)
df_feats_non_sexist.head(10)
# Out:
#   Root  \
# 0   11
# 1   11
# 2    0
# 3   14
# 4   13
# 5   13
#
#                                                                                         Examples  \
# 0  a female, their sexual, a girl, involve great, many important, her husbands, " male, a proper
# 1                        a male, a good, his own, the main, some [UNK], a football, a #, a [UNK]
# 2                                                                                       ' /, - p
# 3                                                                 is quiet, you look, instead of
# 4                                                                          / [UNK], / glpla1so3a
# 5                                                                                   / 3aqtyrrcve
#
#          MI  Count  Sexist  Non-Sexist  Majority label idx Majority label  \
# 0  0.012713   61.0     0.0        61.0                   1     Non-Sexist
# 1  0.002390   12.0     0.0        12.0                   1     Non-Sexist
# 2  0.000789    4.0     0.0         4.0                   1     Non-Sexist
# 3  0.000598    3.0     0.0         3.0                   1     Non-Sexist
# 4  0.000413    2.0     0.0         2.0                   1     Non-Sexist
# 5  0.000238    1.0     0.0         1.0                   1     Non-Sexist
#
#    % majority  Support count  Counter count
# 0    0.984127           61.0            0.0
# 1    0.928571           12.0            0.0
# 2    0.833333            4.0            0.0
# 3    0.800000            3.0            0.0
# 4    0.750000            2.0            0.0
# 5    0.666667            1.0            0.0

# %%
feature_utils.add_merges_train(data['train'], "Subtrees", merge_name="Root 2", K=1000, by_template=True,
                        filter_=lambda w: w[0].startswith("2 "))
# Out:
# filtering
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 feature_utils.add_merges_train(data['train'], "Subtrees", merge_name="Root 2", K=1000, by_template=True,
#       2                         filter_=lambda w: w[0].startswith("2 "))
#
# File ~/ShortcutGrammar/src/features/feature_utils.py:489, in add_merges_train(data, feature_name, merge_name, K, filter_, by_argmax, by_template)
#     485 data[merge_name][key][K] = items
#     486 data["idx_w"][merge_name] = [
#     487     (k, data["idx_w"][key][v[0]]) for k, v in items
#     488 ]
# --> 489 data["mi"][merge_name] = np.concatenate([v[1] for _, v in items], 0)
#     490 data["counts"][merge_name] = np.concatenate([v[2] for _, v in items], 0)
#     491 data["X"][merge_name] = np.array([v[3] for _, v in items]).T
#
# ValueError: need at least one array to concatenate

# %%
feature_utils.get_merged_feature_table_train(data['train'], merge_name="Root 2")
# Out:
#                                            Root  \
# 0                (15 (52 *) (29 (86 *) (82 *)))
# 1                            (15 (52 *) (59 *))
# 2    (15 (52 *) (29 (11 (86 *) (88 *)) (41 *)))
# 3                (15 (52 *) (29 (88 *) (53 *)))
# 4                            (15 (52 *) (59 *))
# ..                                          ...
# 699                          (15 (42 *) (64 *))
# 700                          (15 (42 *) (64 *))
# 701  (15 (52 *) (29 (11 (86 *) (88 *)) (51 *)))
# 702              (15 (52 *) (29 (88 *) (56 *)))
# 703              (15 (52 *) (29 (86 *) (56 *)))
#
#                                                                                                                                                                                                   Examples  \
# 0                                                                                                  for a girl, like a man, of the family, for a woman, with a woman, for a man, on the average, than a man
# 1                                                                                                                    than men, than women, for sex, by men, with women, than girls, and children, with men
# 2    in their sexual relationships, of every great man, by the male ghostbusters, as the right woman, with a female announcer, with a better phone, touch a door handle, through their physical appearance
# 3                                                                 at all times, like old ladies, of female sports, in elementary school, of constant desire, of both men, of other men, of gender equality
# 4                                                                                                                     for women, for men, at home, on espn, or something, as men, in life, on sportscenter
# ..                                                                                                                                                                                                     ...
# 699                                                                                                                                         so much, take care, being sexist, more sensible, more original
# 700                                                                                                                                    be happy, more comfortable, have played, being told, more revolting
# 701                                                                                                       of b grade [UNK], of a department [UNK], in very special [UNK], or a gas [UNK], for a nice [UNK]
# 702                                                                                                       on girls [UNK], with old [UNK], from physical [UNK], as ‘ [UNK], on radio [UNK], of sexual [UNK]
# 703                                                                                                 during their [UNK], of emotional [UNK], with their [UNK], with her [UNK], neck a [UNK], with any [UNK]
#
#                MI  Count  Sexist  Non-Sexist  Majority label idx  \
# 0    1.902986e-03  153.0   153.0         0.0                   0
# 1    1.570102e-03  130.0   130.0         0.0                   0
# 2    5.774881e-04   59.0    59.0         0.0                   0
# 3    5.641701e-04   58.0    58.0         0.0                   0
# 4    2.572510e-04   34.0    34.0         0.0                   0
# ..            ...    ...     ...         ...                 ...
# 699  2.922736e-07    5.0     5.0         0.0                   0
# 700  2.922736e-07    5.0     5.0         0.0                   0
# 701  2.922736e-07    5.0     5.0         0.0                   0
# 702  2.470386e-07    6.0     6.0         0.0                   0
# 703  2.470386e-07    6.0     6.0         0.0                   0
#
#     Majority label  % majority  Support count  Counter count
# 0           Sexist    0.993548          153.0            0.0
# 1           Sexist    0.992424          130.0            0.0
# 2           Sexist    0.983607           59.0            0.0
# 3           Sexist    0.983333           58.0            0.0
# 4           Sexist    0.972222           34.0            0.0
# ..             ...         ...            ...            ...
# 699         Sexist    0.857143            5.0            0.0
# 700         Sexist    0.857143            5.0            0.0
# 701         Sexist    0.857143            5.0            0.0
# 702         Sexist    0.875000            6.0            0.0
# 703         Sexist    0.875000            6.0            0.0
#
# [704 rows x 11 columns]

# %%
#df_trees_sexist = df_resultant[df_resultant['sexist'] == True].reset_index(drop = True)
#df_trees_sexist

# %%
#df_trees_sexist.to_csv('Sexist_Instances.csv', index = False)

# %%
#df_trees_sexist = pd.read_csv(os.path.join(os.path.expanduser('~/ShortcutGrammar'), 'Sexist_Instances.csv'))
#df_trees_sexist.head()

# %%
#df_trees_non_sexist = df_resultant[df_resultant['sexist'] == False].reset_index(drop = True)

# %%
#df_trees_non_sexist.to_csv('Non_Sexist_Instances.csv', index = False)

# %%
#df_trees_non_sexist = pd.read_csv(os.path.join(os.path.expanduser('~/ShortcutGrammar'), 'Non_Sexist_Instances.csv'))

# %%
#df_trees_non_sexist

# %%
#df_int_s = df_trees_sexist[df_trees_sexist['tree'].str.contains(r'\(57')]
#df_int_s.head()

# %%
#df_int_ns = df_trees_non_sexist[df_trees_non_sexist['tree'].str.contains(r'\(57')]

# %%
#df_int_ns[df_int_ns['misclassification_number'] >=3].head()
