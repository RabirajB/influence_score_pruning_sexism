# %%
import os
if os.getcwd().endswith("notebooks"):
    os.chdir("..")

import importlib
from IPython.display import display, Markdown, Latex
import numpy as np
import pandas as pd
pd.set_option("display.max_colwidth", None)
pd.set_option('display.max_rows', 500)

from src.utils import tree_utils
from src.features import feature_utils

# %%
data = feature_utils.load_trees_from_predictions(output_dir="/home/rabiraj.bandyopadhyay/ShortcutGrammar/src/output/ood_3",
                                                 dataset="ood_3")
# Out:
# parsed 19705/19992 trees
# parsed 3936/3997 trees

# %%
data['dataset']
# Out:
# 'ood_3'

# %%
df_tree = pd.DataFrame(data['train'])

# %%
df_tree.head()
# Out:
#   uid  \
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4
#
#                                                                                                                                                      sentence  \
# 0                        In Nigeria, if you rape a woman, the men rape you back! #NSFW "In Nigeria, if you rape a woman, guys rape you back!" by [USER] [URL]
# 1                                                                                                                                     Then, she's a keeper. 😉
# 2  This is like the Metallica video where the poor mutilated bastard was saying "Please kill me" over and over again, only with emojis instead of Morse code.
# 3                                                                                                                                                      woman?
# 4                                                                                                                              I bet she wished she had a gun
#
#         label  \
# 0  non-sexist
# 1  non-sexist
# 2  non-sexist
# 3  non-sexist
# 4  non-sexist
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  tree  \
# 0  [[[(88 in), (93 nigeria)], [,]], [[(17\n  (2\n    (2\n      (2\n        (26\n          (11\n            (8\n              (59 if)\n              (9 (62 you) (10 (90 rape) (18 (85 a) (72 woman)))))\n            (63 ,))\n          (9\n            (18 (85 the) (72 men))\n            (30 (25 (95 rape) (45 you)) (37 back))))\n        (34 !))\n      (2 (35 #) (43 nsfw)))\n    (2\n      (2\n        (19\n          (78 ")\n          (1\n            (11 (15 (88 in) (93 nigeria)) (63 ,))\n            (1\n              (26\n                (11\n                  (8\n                    (59 if)\n                    (9\n                      (62 you)\n                      (10 (90 rape) (18 (85 a) (72 woman)))))\n                  (63 ,))\n                (9 (52 guys) (25 (25 (95 rape) (45 you)) (37 back))))\n              (34 !))))\n        (78 "))\n      (2 (65 by) (2 (75 [) (23 (40 user) (38 ]))))))\n  (75 [)), (40 url)], []]]]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[[(11 (84 then) (63 ,)), (9 (62 she) (10 (6 (92 ') (71 s)) (22 (85 a) (44 keeper))))], [.]], [😉]]
# 2                                                                                                                                                                                                                                                                                                       [[[(26\n  (26\n    (9\n      (64 this)\n      (30\n        (47 is)\n        (22 (80 like) (18 (85 the) (29 (69 [UNK]) (76 video))))))\n    (28\n      (33 where)\n      (9\n        (18 (85 the) (29 (54 poor) (29 (54 mutilated) (76 bastard))))\n        (30\n          (47 was)\n          (22\n            (22\n              (80 saying)\n              (18\n                (19 (78 ") (13 (67 please) (25 (95 kill) (45 me))))\n                (78 ")))\n            (15 (88 over) (18 (86 and) (37 over))))))))\n  (50 again)), (28 (63 ,) (28 (89 only) (15 (88 with) (57 [UNK]))))], [(89 instead), (15 (88 of) (18 (69 [UNK]) (41 code)))]], [.]]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [[woman], [?]]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [[i], [[bet], [(62 she), (10 (74 wished) (9 (62 she) (10 (90 had) (18 (85 a) (72 gun)))))]]]
#
#             y
# 0  non-sexist
# 1  non-sexist
# 2  non-sexist
# 3  non-sexist
# 4  non-sexist

# %%
df_tree.columns
# Out:
# Index(['uid', 'sentence', 'label', 'tree', 'y'], dtype='object')

# %%
df_tree[df_tree['label'] == 'sexist'].head()
# Out:
#    uid  \
# 6    6
# 8    8
# 9    9
# 14  14
# 15  15
#
#                                                                                                                                                                                                                                                       sentence  \
# 6                                                                                                                                                                                         [USER] Leg day is easy. Hot girls who wear miniskirts get asked out.
# 8   I get a new pussy every other week or whenever i want really. Didnt have to learn how to either from YouTube videos. Also PUAs dont get laid. At best they get 5/10 asian ladies after spending years pretending to be something they aren't. Its pathetic
# 9         I agree with that but at the same time I know myself well enough to say I can’t love a woman. The minute she begins to hit the wall and some hotter, younger women enters the picture, it’s time for impulse control because I’m going to want that.
# 14                                                                                                                                                                                           O come on there's no way any men are attracted to her shes a pig🙄
# 15                                                 democrats from Minnesota (leftist muzzie shithole) are the dumbest anti-americans there are. KLobuchar, one of the reps. is a dumb bitch who has a moronic position on the tax bill. Fuck this stupid woman
#
#      label  \
# 6   sexist
# 8   sexist
# 9   sexist
# 14  sexist
# 15  sexist
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               tree  \
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[[(26\n  (11 (75 [) (23 (40 user) (38 ])))\n  (9 (18 (85 leg) (72 day)) (30 (47 is) (32 easy)))), (36 .)], [(18 (18 (54 hot) (52 girls)) (28 (86 who) (13 (95 wear) (69 [UNK])))), (30 (47 get) (22 (61 asked) (37 out)))]], [.]]
# 8   [[[(26\n  (9\n    (62 i)\n    (10\n      (25 (95 get) (18 (85 a) (29 (54 new) (76 pussy))))\n      (22 (85 every) (29 (54 other) (76 week)))))\n  (28 (86 or) (22 (16 (39 whenever) (62 i)) (68 want)))), (50 really)], [.]], [[(26\n  (26\n    (26 (48 didnt) (13 (68 have) (4 (82 to) (42 learn))))\n    (28\n      (60 how)\n      (4 (82 to) (13 (42 either) (15 (88 from) (93 youtube))))))\n  (50 videos)), (36 .)], [(73 also), (26\n  (11\n    (26\n      (11\n        (9 (64 puas) (30 (48 dont) (13 (51 get) (32 laid))))\n        (36 .))\n      (9\n        (15 (88 at) (93 best))\n        (9\n          (62 they)\n          (10\n            (25\n              (95 get)\n              (18\n                (56 5)\n                (14 (14 (49 /) (56 10)) (29 (54 asian) (76 ladies)))))\n            (15\n              (88 after)\n              (18\n                (80 spending)\n                (18\n                  (52 years)\n                  (28\n                    (60 pretending)\n                    (4\n                      (82 to)\n                      (13\n                        (51 be)\n                        (22\n                          (39 something)\n                          (9\n                            (62 they)\n                            (10 (58 aren) (6 (92 ') (71 t)))))))))))))))\n    (36 .))\n  (9 (46 its) (32 pathetic)))]]]
# 9                                                                                                                                                                                                                   [[[(26\n  (26\n    (9 (62 i) (10 (42 agree) (15 (88 with) (93 that))))\n    (28\n      (33 but)\n      (9\n        (15 (88 at) (18 (85 the) (29 (54 same) (76 time))))\n        (9 (62 i) (10 (90 know) (45 myself))))))\n  (50 well)), (28\n  (60 enough)\n  (4\n    (82 to)\n    (13\n      (74 say)\n      (9\n        (62 i)\n        (10\n          (58 can)\n          (31\n            (92 ’)\n            (12 (71 t) (13 (95 love) (18 (85 a) (72 woman))))))))))], [.]], [[(85 the), (77 minute)], [(11\n  (26\n    (9\n      (62 she)\n      (10\n        (68 begins)\n        (4 (82 to) (13 (95 hit) (18 (85 the) (72 wall))))))\n    (28 (86 and) (18 (85 some) (72 hotter))))\n  (63 ,)), (1\n  (11\n    (9\n      (18 (54 younger) (52 women))\n      (30 (57 [UNK]) (18 (85 the) (72 picture))))\n    (63 ,))\n  (1\n    (26\n      (9\n        (62 it)\n        (10\n          (6 (92 ’) (71 s))\n          (22 (89 time) (15 (88 for) (18 (54 impulse) (52 control))))))\n      (28\n        (33 because)\n        (9\n          (62 i)\n          (10\n            (6 (92 ’) (71 m))\n            (22 (60 going) (4 (82 to) (25 (95 want) (45 that))))))))\n    (36 .)))]]]
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [[[o], [(25 (61 come) (37 on)), (9\n  (62 there)\n  (10\n    (6 (92 ') (71 s))\n    (22\n      (85 no)\n      (29\n        (77 way)\n        (9\n          (18 (85 any) (72 men))\n          (30 (47 are) (22 (60 attracted) (4 (82 to) (45 her)))))))))]], [[shes], [(85 a), (69 [UNK])]]]
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [[[(9\n  (18\n    (55 democrats)\n    (15\n      (88 from)\n      (18\n        (3\n          (65 minnesota)\n          (3\n            (65 ( ) (3 (65 leftist) (29 (83 muzzie) (91 shithole)))))\n          (81 )))))\n  (30\n    (47 are)\n    (22\n      (85 the)\n      (29 (54 dumbest) (29 (56 anti) (14 (49 -) (56 americans))))))), (28 (64 there) (47 are))], [.]], [[(26\n  (9\n    (18\n      (69 [UNK])\n      (14\n        (14\n          (63 ,)\n          (18 (55 one) (15 (88 of) (18 (85 the) (72 reps)))))\n        (36 .)))\n    (30 (47 is) (22 (85 a) (29 (54 dumb) (76 bitch)))))\n  (28\n    (86 who)\n    (30\n      (47 has)\n      (22\n        (22 (85 a) (29 (83 moronic) (91 position)))\n        (15 (88 on) (18 (85 the) (29 (83 tax) (91 bill)))))))), (36 .)], [(46 fuck), (22 (85 this) (29 (54 stupid) (76 woman)))]]]
#
#          y
# 6   sexist
# 8   sexist
# 9   sexist
# 14  sexist
# 15  sexist

# %%
#df_tree.to_csv('train_trees.csv')

# %%
feature_utils.add_features_train(data['train'], "Subtrees", feature_utils.pcfg_subtrees_by_depth(7))
subtrees = feature_utils.get_subtree_feature_table_train(data['train'], label_name = "sexism")
subtrees.head(10)
# Out:
# 370299 Subtrees features
#   Root Subtree  Yield        MI   Count  Sexist  Non-Sexist Majority label  \
# 0   76  (76 *)  bitch  0.014388   223.0     5.0       218.0     Non-Sexist
# 1   64  (64 *)  women  0.013725   882.0   349.0       533.0     Non-Sexist
# 2   72  (72 *)  bitch  0.012709   196.0     4.0       192.0     Non-Sexist
# 3   38  (38 *)      ]  0.007527  3031.0  2651.0       380.0         Sexist
# 4   75  (75 *)      [  0.007490  3032.0  2651.0       381.0         Sexist
# 5   76  (76 *)   cunt  0.006952   111.0     3.0       108.0     Non-Sexist
# 6   40  (40 *)    url  0.006617  2286.0  2024.0       262.0         Sexist
# 7   76  (76 *)  whore  0.006060    95.0     2.0        93.0     Non-Sexist
# 8   52  (52 *)  women  0.005033  1245.0   723.0       522.0         Sexist
# 9   72  (72 *)  pussy  0.003400    70.0     7.0        63.0     Non-Sexist
#
#    % majority
# 0    0.973333
# 1    0.604072
# 2    0.974747
# 3    0.874382
# 4    0.874094
# 5    0.964602
# 6    0.885052
# 7    0.969072
# 8    0.580593
# 9    0.888889

# %%
subtrees[subtrees['Majority label'] == 'Non-Sexist'].reset_index(drop = True)
# Out:
#       Root  \
# 0       76
# 1       64
# 2       72
# 3       76
# 4       76
# ...    ...
# 88757   11
# 88758   18
# 88759   18
# 88760   52
# 88761   52
#
#                                                                                          Subtree  \
# 0                                                                                         (76 *)
# 1                                                                                         (64 *)
# 2                                                                                         (72 *)
# 3                                                                                         (76 *)
# 4                                                                                         (76 *)
# ...                                                                                          ...
# 88757  (11 (26 (11 (75 *) (23 (40 *) (38 *))) (9 (18 (85 *) (72 *)) (30 (47 *) (32 *)))) (36 *))
# 88758                                                             (18 (85 *) (29 (54 *) (76 *)))
# 88759                                                             (18 (85 *) (29 (54 *) (76 *)))
# 88760                                                                                     (52 *)
# 88761                                                                                     (52 *)
#
#                             Yield        MI  Count  Sexist  Non-Sexist  \
# 0                           bitch  0.014388  223.0     5.0       218.0
# 1                           women  0.013725  882.0   349.0       533.0
# 2                           bitch  0.012709  196.0     4.0       192.0
# 3                            cunt  0.006952  111.0     3.0       108.0
# 4                           whore  0.006060   95.0     2.0        93.0
# ...                           ...       ...    ...     ...         ...
# 88757  [ user ] leg day is easy .  0.000060    1.0     0.0         1.0
# 88758          that fat landwhale  0.000060    1.0     0.0         1.0
# 88759             that first hand  0.000060    1.0     0.0         1.0
# 88760                        folk  0.000060    1.0     0.0         1.0
# 88761                       hippy  0.000060    1.0     0.0         1.0
#
#       Majority label  % majority
# 0         Non-Sexist    0.973333
# 1         Non-Sexist    0.604072
# 2         Non-Sexist    0.974747
# 3         Non-Sexist    0.964602
# 4         Non-Sexist    0.969072
# ...              ...         ...
# 88757     Non-Sexist    0.666667
# 88758     Non-Sexist    0.666667
# 88759     Non-Sexist    0.666667
# 88760     Non-Sexist    0.666667
# 88761     Non-Sexist    0.666667
#
# [88762 rows x 9 columns]

# %%
subtrees_sexist = subtrees[subtrees['Majority label'] == 'Sexist'].reset_index(drop = True)

# %%
feature_utils.add_merges_train(data['train'], "Subtrees", K=2000, merge_name="Subtree groups",
                         filter_=lambda w: w[0].count("*") <=2)
# Out:
# filtering

# %%
df_feats = feature_utils.get_merged_feature_table_train(data['train'], merge_name="Subtree groups")

# %% [markdown]
# To visualize the most discriminative patterns, we group the highest-ranked subtrees according to their root label and majority class label.

# %%
df_feats_sexist = df_feats[df_feats['Majority label'] == 'Sexist'].reset_index(drop = True)
df_feats_sexist.head(5)
#df_feats_sexist.head(10).to_csv('sexist_roots.csv')
# Out:
#   Root  \
# 0   54
# 1   95
# 2   93
# 3   29
# 4   91
#
#                                                                                                   Examples  \
# 0                                       attention, dumb, slutty, modern, lying, western, feminazi, typical
# 1                                                   hang, ruin, please, fucked, stick, demand, wants, feed
# 2                                        men, pussy, chad, politics, themselves, bitches, sluts, attention
# 3  [UNK] bitch, little bitch, old hag, dumb bitch, attention whore, stupid bitch, fucking bitch, dumb cunt
# 4                                              pass, nature, accusation, pussy, count, species, smv, range
#
#          MI  Count  Sexist  Non-Sexist  Majority label idx Majority label  \
# 0  0.001320  109.0   109.0         0.0                   0         Sexist
# 1  0.000997   85.0    85.0         0.0                   0         Sexist
# 2  0.000984   84.0    84.0         0.0                   0         Sexist
# 3  0.000943   81.0    81.0         0.0                   0         Sexist
# 4  0.000903   78.0    78.0         0.0                   0         Sexist
#
#    % majority  Support count  Counter count
# 0    0.990991          109.0            0.0
# 1    0.988506           85.0            0.0
# 2    0.988372           84.0            0.0
# 3    0.987952           81.0            0.0
# 4    0.987500           78.0            0.0

# %%
df_feats_non_sexist = df_feats[df_feats['Majority label'] == 'Non-Sexist'].reset_index(drop = True)
df_feats_non_sexist.head()
#df_feats_non_sexist.to_csv('non_sexist_roots.csv')
# Out:
#   Root  \
# 0   11
# 1   13
# 2   10
# 3   14
# 4   14
#
#                                                                                     Examples  \
# 0       true ., nope ,, funny how, please ., bitch ,, the moment, interesting ., if anything
# 1  destroy you, get fucked, get pussy, be like, never forget, get raped, be strong, kill her
# 2             ' know, love this, totally agree, - she, should have, disagrees with, speak of
# 3                                             / 10, , bitch, , whore, , kids, - 3, : 11, / 7
# 4                                                                    - year, - old, . s, - -
#
#          MI  Count  Sexist  Non-Sexist  Majority label idx Majority label  \
# 0  0.002059   31.0     0.0        31.0                   1     Non-Sexist
# 1  0.000554    9.0     0.0         9.0                   1     Non-Sexist
# 2  0.000423    7.0     0.0         7.0                   1     Non-Sexist
# 3  0.000423    7.0     0.0         7.0                   1     Non-Sexist
# 4  0.000233    4.0     0.0         4.0                   1     Non-Sexist
#
#    % majority  Support count  Counter count
# 0    0.969697           31.0            0.0
# 1    0.909091            9.0            0.0
# 2    0.888889            7.0            0.0
# 3    0.888889            7.0            0.0
# 4    0.833333            4.0            0.0

# %%
feature_utils.add_merges_train(data['train'], "Subtrees", merge_name="Root 11", K=1000, by_template=True,
                        filter_=lambda w: w[0].startswith("(11 "))
# Out:
# filtering

# %%
df_feats = feature_utils.get_merged_feature_table_train(data['train'], merge_name="Root 11")

# %%
df_feats_sexist = df_feats[df_feats['Majority label'] == 'Sexist'].reset_index(drop = True)
df_feats_sexist.head()
# Out:
#                                                                                                                                                                Root  \
# 0                                                                                                                                    (11 (82 *) (26 (89 *) (70 *)))
# 1                                                                        (11 (29 (29 (11 (11 (86 *) (88 *)) (88 *)) (41 *)) (15 (52 *) (59 *))) (26 (89 *) (70 *)))
# 2                                                                                                                                    (11 (15 (49 *) (45 *)) (48 *))
# 3  (11 (27 (27 (14 (8 (65 *) (26 (58 *) (91 *))) (2 (87 *) (39 *))) (15 (52 *) (29 (86 *) (56 *)))) (15 (52 *) (29 (11 (86 *) (88 *)) (41 *)))) (13 (72 *) (50 *)))
# 4                                                             (11 (29 (29 (59 *) (15 (8 (65 *) (26 (89 *) (70 *))) (46 *))) (15 (52 *) (59 *))) (26 (89 *) (70 *)))
#
#   Examples        MI  Count  Sexist  Non-Sexist  Majority label idx  \
# 0           0.000081    0.0     0.0         0.0                   0
# 1           0.000081    0.0     0.0         0.0                   0
# 2           0.000081    0.0     0.0         0.0                   0
# 3           0.000081    0.0     0.0         0.0                   0
# 4           0.000081    0.0     0.0         0.0                   0
#
#   Majority label  % majority  Support count  Counter count
# 0         Sexist         0.5            0.0            0.0
# 1         Sexist         0.5            0.0            0.0
# 2         Sexist         0.5            0.0            0.0
# 3         Sexist         0.5            0.0            0.0
# 4         Sexist         0.5            0.0            0.0

# %%
df_feats_non_sexist = df_feats[df_feats['Majority label'] == 'Non-Sexist'].reset_index(drop  = True)
df_feats_non_sexist.head()
# Out:
#                                          Root  \
# 0              (11 (11 (86 *) (88 *)) (88 *))
# 1                          (11 (86 *) (88 *))
# 2                          (11 (86 *) (88 *))
# 3  (11 (29 (86 *) (82 *)) (26 (89 *) (70 *)))
# 4              (11 (11 (86 *) (88 *)) (88 *))
#
#                                                                                                                                Examples  \
# 0   every high school, every little fucking, all these [UNK], the best damn, the [UNK] special, a full [UNK], a grand slam, a hat [UNK]
# 1                                                       a male, a good, his own, the main, some [UNK], a football, a [UNK], every great
# 2                                 a female, their sexual, a girl, involve great, her husbands, many important, a proper, their physical
# 3                       the women ' s, a man ' s, her husband ' s, a mother ’ s, this girl ' s, the women ’ s, his wife ’ s, a dude ' s
# 4  a good house, " manly ", the strong lead, their individual career, the mens [UNK], the female football, the show ", “ greater career
#
#          MI  Count  Sexist  Non-Sexist  Majority label idx Majority label  \
# 0  0.074297  333.0     0.0       333.0                   1     Non-Sexist
# 1  0.048126  221.0     0.0       221.0                   1     Non-Sexist
# 2  0.015936   76.0     0.0        76.0                   1     Non-Sexist
# 3  0.007607   37.0     0.0        37.0                   1     Non-Sexist
# 4  0.004040   20.0     0.0        20.0                   1     Non-Sexist
#
#    % majority  Support count  Counter count
# 0    0.997015          333.0            0.0
# 1    0.995516          221.0            0.0
# 2    0.987179           76.0            0.0
# 3    0.974359           37.0            0.0
# 4    0.954545           20.0            0.0

# %%
#df_trees_sexist = df_resultant[df_resultant['sexist'] == True].reset_index(drop = True)
#df_trees_sexist

# %%
#df_trees_sexist.to_csv('Sexist_Instances.csv', index = False)

# %%
#df_trees_sexist = pd.read_csv(os.path.join(os.path.expanduser('~/ShortcutGrammar'), 'Sexist_Instances.csv'))
#df_trees_sexist.head()

# %%
#df_trees_non_sexist = df_resultant[df_resultant['sexist'] == False].reset_index(drop = True)

# %%
#df_trees_non_sexist.to_csv('Non_Sexist_Instances.csv', index = False)

# %%
#df_trees_non_sexist = pd.read_csv(os.path.join(os.path.expanduser('~/ShortcutGrammar'), 'Non_Sexist_Instances.csv'))

# %%
#df_trees_non_sexist

# %%
#df_int_s = df_trees_sexist[df_trees_sexist['tree'].str.contains(r'\(57')]
#df_int_s.head()

# %%
#df_int_ns = df_trees_non_sexist[df_trees_non_sexist['tree'].str.contains(r'\(57')]

# %%
#df_int_ns[df_int_ns['misclassification_number'] >=3].head()
